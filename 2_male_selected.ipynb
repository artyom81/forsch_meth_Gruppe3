# %%
import os

input_directory = "/Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/männlich"
output_directory = "/Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected"
os.makedirs(output_directory, exist_ok=True)
namespaces = {'tei': 'http://www.tei-c.org/ns/1.0'}


allowed_places = ["Berlin", "Leipzig", "Stuttgart", "Frankfurt am Main", "Heidelberg"] # Erlaubte Veröffentlichungsorte


for filename in os.listdir(input_directory):
    if filename.endswith(".xml"):
        file_path = os.path.join(input_directory, filename)

        with open(file_path, 'rb') as file:
            xml_content = file.read()

        tree = etree.fromstring(xml_content)

        # Informationen zu Veröffentlichungsort und Datum extrahieren
        pub_place_elements = tree.xpath('//tei:fileDesc/tei:sourceDesc/tei:biblFull/tei:publicationStmt/tei:pubPlace', namespaces=namespaces)
        if pub_place_elements:
            pub_place = pub_place_elements[0].text

        pub_year = int(filename.split("_")[-1].split(".")[0])

        if 1800 <= pub_year <= 1850 and pub_place in allowed_places:
            selected_path = os.path.join(output_directory, filename)
            os.rename(file_path, selected_path)
            print(f"Datei: {filename}, erfüllt die Kriterien, verschoben nach: {output_directory}")
        else:
            print(f"Datei: {filename}, erfüllt die Kriterien für das Jahr nicht.")

print("Dateien, die den Kriterien entsprechen, wurden in den ausgewählten Ordner verschoben.")
# Out:
# Datei: nettelbeck_lebensbeschreibung03_1823.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: kleist_kaethchen_1810.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: pocci_komoedienbuechlein06_1877.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: abschatz_gedichte_1704.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hunold_gedichte_1702.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: gutzkow_charaktere_1835.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: pocci_komoedienbuechlein01_1859.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wagner_kindermoerderin_1776.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: kosegarten_poesieen03_1802.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: laube_europa03_1837.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: platen_oedipus_1829.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: eichendorff_ahnung_1815.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: goethe_leben02_1812.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: goethe_werther01_1774.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wezel_belphegor01_1776.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: silesius_seelenlust01_1657.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hoffmannswaldau_gedichte04_1708.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: buerger_gedichte_1778.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: logau_sinngetichte_1654.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: meinhold_bernsteinhexe_1843.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: pueckler_briefe04_1831.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: kuernberger_amerikamuede_1855.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: klopstock_messias03_1769.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: suppius_oden_1749.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: goethe_goetz_1773.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: arnim_wunderhorn03_1808.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: buechner_danton_1835.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei
TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: scheffner_leben_1823.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: bismarck_erinnerungen01_1898.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: vischer_auch01_1879.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: rabener_sammlung01_1751.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: lasswitz_planeten02_1897.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: laube_europa0101_1833.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: hebel_gedichte_1803.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: brockes_vergnuegen05_1736.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hagedorn_sammlung01_1742.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: fontane_brandenburg04_1882.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schwab_sagen02_1839.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: schnitzler_liebelei_1896.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hoelty_gedichte_1783.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: holz_buch_1886.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: alexis_ruhe02_1852.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: storm_aquis_1877.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: moerike_nolten01_1832.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: kleist_krug_1811.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: uz_gedichte_1755.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: boerne_paris03_1833.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: paul_katzenberger01_1809.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: musaeus_reisen01_1779.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: goethe_iphigenie_1787.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: raabe_sperlingsgasse_1857.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hippel_lebenslaeufe0302_1781.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hoffmann_elixiere02_1816.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: eichendorff_dichter_1834.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: rueckert_brahmane06_1839.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: fontane_brandenburg02_1863.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: seume_syrakus_1803.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: heine_reisebilder04_1831.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: klinger_zwillinge_1796.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: stifter_steine02_1853.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: may_kurdistan_1892.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schulz_reise03_1795.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: lessing_nathan_1779.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: gressel_grabgedichte_1716.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: eichendorff_taugenichts_1826.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: hippel_lebenslaeufe01_1778.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: kortum_jobsiade03_1799.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: fontane_brandenburg01_1862.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: anzengruber_gwissenswurm_1874.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: reuter_ehrenfried_1700.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: candidus_christus_1854.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: paul_hesperus02_1795.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: pueckler_briefe01_1830.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hebbel_magdalene_1844.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: rueckert_brahmane03_1837.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: kleist_fruehling_1749.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hippel_lebenslaeufe02_1779.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schwab_sagen03_1840.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: hoffmann_floh_1822.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: olearius_reise_1647.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: raabe_stopfkuchen_1891.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: brentano_kasperl_1838.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: laukhard_leben05_1802.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: tieck_lovell01_1795.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: weise_theatrum_1683.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: stieler_venus_1660.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wieland_agathon02_1767.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: heine_reisebilder01_1826.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: zachariae_schriften01_1763.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: bodmer_sammlung12_1744.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: milton_paradies02_1763.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: herwegh_gedichte02_1843.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: laukhard_leben0402_1797.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schiller_stuart_1801.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: keller_sinngedicht_1882.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: keller_heinrich01_1854.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: tieck_sternbald02_1798.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: thuemmel_wilhelmine_1764.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: moerike_mozart_1856.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: bodmer_sammlung06_1742.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hoffmannswaldau_gedichte06_1709.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: gleim_versuch02_1745.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: brockes_vergnuegen08_1746.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: klopstock_gelehrtenrepublik_1774.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hauff_phantasien_1827.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: meyer_jenatsch_1876.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: boerne_paris05_1834.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schnitzler_reigen_1903.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: miller_siegwart01_1776.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wedekind_pandora_1902.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: retif_mensch_1785.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: ludwig_erbfoerster_1853.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: goethe_wahlverw01_1809.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: heine_reisebilder02_1827.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: fontane_wuthenow_1883.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wieland_agathon01_1766.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: brockes_vergnuegen02_1727.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: pestalozzi_lienhard04_1787.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: bernd_lebensbeschreibung_1738.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schiller_geisterseher_1789.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: rabener_sammlung03_1752.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: klingemann_nachtwachen_1805.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: paul_loge02_1793.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: gleim_versuch01_1744.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: george_seele_1897.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: hofmannswaldau_uebersetzungen_1679.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: wieland_oberon_1780.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: melander_jocoseria01_1605.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: kotzebue_erinnerungen02_1804.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: boerne_paris04_1833.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: bierbaum_stilpe_1897.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: weckherlin_gedichte_1641.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: alexis_ruhe05_1852.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: paul_flegeljahre02_1804.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: fleming_poemata_1642.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: arnim_wunderhorn02_1808.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: richardson_clarissa01_1748.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: stolbergstolberg_gedichte_1779.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: eckermann_goethe02_1836.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: hoffmann_nachtstuecke02_1817.TEI-P5.xml, erfüllt die Kriterien, verschoben nach: /Users/a1/Documents/0. UNI/6. SS 2023/Forsch_design/projekt/output/male_selected
# Datei: lohenstein_sophonisbe_1680.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: leisewitz_julius_1776.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Datei: schiller_domkarlos_1787.TEI-P5.xml, erfüllt die Kriterien für das Jahr nicht.
# Dateien, die den Kriterien entsprechen, wurden in den ausgewählten Ordner verschoben.
